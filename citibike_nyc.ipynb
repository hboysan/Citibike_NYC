# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime

# %%
march_18 = "Resources/201803-citibike-tripdata.csv"

march_18_df = pd.read_csv(march_18).head(100000)
march_18_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               816  2018-03-01 02:29:13.7270  2018-03-01 02:42:50.1460
# 1               235  2018-03-01 05:12:37.0320  2018-03-01 05:16:32.1010
# 2              1250  2018-03-01 05:45:49.9000  2018-03-01 06:06:39.9080
# 3               741  2018-03-01 06:54:19.6150  2018-03-01 07:06:40.9790
# 4               727  2018-03-01 07:08:38.8610  2018-03-01 07:20:46.8500
# 5               341  2018-03-01 07:22:50.3340  2018-03-01 07:28:31.9040
# 6               697  2018-03-01 07:22:51.8030  2018-03-01 07:34:29.2430
# 7               407  2018-03-01 07:33:26.7530  2018-03-01 07:40:14.1560
# 8               978  2018-03-01 07:45:31.9580  2018-03-01 08:01:50.6420
# 9               396  2018-03-01 07:46:59.3130  2018-03-01 07:53:35.5640
# 10              284  2018-03-01 07:48:39.7560  2018-03-01 07:53:24.6560
# 11             1246  2018-03-01 08:19:17.5790  2018-03-01 08:40:03.9350
# ...

# %%
march_18_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
march_18_df['starttime'] = march_18_df['starttime'].astype('datetime64')

# %%
march_18_df['stoptime'] = march_18_df['stoptime'].astype('datetime64')

# %%
march_18_df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                    int64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# Create a filtered dataframe from specific columns
march_18_cols = ["tripduration", "starttime", "stoptime", "start station id", "start station name", "start station latitude", 
               "start station longitude", "end station id", "end station name", "end station latitude", "end station longitude", 
               "bikeid", "usertype", "birth year", "gender"]
march_18_transformed_df = march_18_df[march_18_cols].copy()

# Rename the column headers
march_18_transformed_df = march_18_transformed_df.rename(columns={"tripduration": "tripduration",
                                                          "starttime": "starttime",
                                                          "stoptime": "stoptime",
                                                         "start station id": "start_staion_id",
                                                         "start station name": "start_station_name",
                                                        "start station latitude": "start_station_lat",
                                                         "start station longitude": "start_station_long", 
                                                        "end station id": "end_station_id", 
                                                        "end station name": "end_station_name", 
                                                        "end station latitude": "end_station_lat", 
                                                        "end station longitude": "end_station_long", 
                                                        "bikeid": "bikeid", "usertype": "usertype", "birth year": "birth_year", 
                                                        "gender": "gender"})

march_18_transformed_df
# Out:
#        tripduration               starttime                stoptime  \
# 0               816 2018-03-01 02:29:13.727 2018-03-01 02:42:50.146
# 1               235 2018-03-01 05:12:37.032 2018-03-01 05:16:32.101
# 2              1250 2018-03-01 05:45:49.900 2018-03-01 06:06:39.908
# 3               741 2018-03-01 06:54:19.615 2018-03-01 07:06:40.979
# 4               727 2018-03-01 07:08:38.861 2018-03-01 07:20:46.850
# 5               341 2018-03-01 07:22:50.334 2018-03-01 07:28:31.904
# 6               697 2018-03-01 07:22:51.803 2018-03-01 07:34:29.243
# 7               407 2018-03-01 07:33:26.753 2018-03-01 07:40:14.156
# 8               978 2018-03-01 07:45:31.958 2018-03-01 08:01:50.642
# 9               396 2018-03-01 07:46:59.313 2018-03-01 07:53:35.564
# 10              284 2018-03-01 07:48:39.756 2018-03-01 07:53:24.656
# 11             1246 2018-03-01 08:19:17.579 2018-03-01 08:40:03.935
# 12               78 2018-03-01 08:27:09.236 2018-03-01 08:28:27.278
# ...

# %%
march_18_transformed_df.dtypes
# Out:
# tripduration                   int64
# starttime             datetime64[ns]
# stoptime              datetime64[ns]
# start_staion_id                int64
# start_station_name            object
# start_station_lat            float64
# start_station_long           float64
# end_station_id                 int64
# end_station_name              object
# end_station_lat              float64
# end_station_long             float64
# bikeid                         int64
# usertype                      object
# birth_year                     int64
# gender                         int64
# dtype: object

# %%
march_18_transformed_df['bikeid'] = march_18_transformed_df.index

# %%
march_18_transformed_df.columns

# %%
march_19 = "Resources/201903-citibike-tripdata.csv"

march_19_df = pd.read_csv(march_19).head(100000)
march_19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1463  2019-03-01 00:00:16.0970  2019-03-01 00:24:39.3880
# 1               285  2019-03-01 00:00:32.3850  2019-03-01 00:05:18.1830
# 2               686  2019-03-01 00:00:47.7970  2019-03-01 00:12:14.3090
# 3               442  2019-03-01 00:01:01.2090  2019-03-01 00:08:23.7510
# 4              2913  2019-03-01 00:01:09.2810  2019-03-01 00:49:42.3810
# 5              1682  2019-03-01 00:01:27.1150  2019-03-01 00:29:29.7530
# 6               769  2019-03-01 00:01:30.0590  2019-03-01 00:14:19.9170
# 7               483  2019-03-01 00:01:33.0960  2019-03-01 00:09:36.4430
# 8               472  2019-03-01 00:01:37.0240  2019-03-01 00:09:29.4480
# 9              3198  2019-03-01 00:02:01.6940  2019-03-01 00:55:20.6360
# 10              909  2019-03-01 00:02:10.9000  2019-03-01 00:17:20.1810
# 11              175  2019-03-01 00:02:09.5280  2019-03-01 00:05:05.5230
# ...

# %%
march_19_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
march_19_df['starttime'] = march_19_df['starttime'].astype('datetime64')
march_19_df['stoptime'] = march_19_df['stoptime'].astype('datetime64')

# %%
march_19_df.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# Create a filtered dataframe from specific columns
march_19_cols = ["tripduration", "starttime", "stoptime", "start station id", "start station name", "start station latitude", 
               "start station longitude", "end station id", "end station name", "end station latitude", "end station longitude", 
               "bikeid", "usertype", "birth year", "gender"]
march_19_transformed_df = march_19_df[march_19_cols].copy()

# Rename the column headers
march_19_transformed_df = march_19_transformed_df.rename(columns={"tripduration": "tripduration",
                                                          "starttime": "starttime",
                                                          "stoptime": "stoptime",
                                                         "start station id": "start_staion_id",
                                                         "start station name": "start_station_name",
                                                        "start station latitude": "start_station_lat",
                                                         "start station longitude": "start_station_long", 
                                                        "end station id": "end_station_id", 
                                                        "end station name": "end_station_name", 
                                                        "end station latitude": "end_station_lat", 
                                                        "end station longitude": "end_station_long", 
                                                        "bikeid": "bikeid", "usertype": "usertype", "birth year": "birth_year", 
                                                        "gender": "gender"})

march_19_transformed_df
# Out:
#        tripduration               starttime                stoptime  \
# 0              1463 2019-03-01 00:00:16.097 2019-03-01 00:24:39.388
# 1               285 2019-03-01 00:00:32.385 2019-03-01 00:05:18.183
# 2               686 2019-03-01 00:00:47.797 2019-03-01 00:12:14.309
# 3               442 2019-03-01 00:01:01.209 2019-03-01 00:08:23.751
# 4              2913 2019-03-01 00:01:09.281 2019-03-01 00:49:42.381
# 5              1682 2019-03-01 00:01:27.115 2019-03-01 00:29:29.753
# 6               769 2019-03-01 00:01:30.059 2019-03-01 00:14:19.917
# 7               483 2019-03-01 00:01:33.096 2019-03-01 00:09:36.443
# 8               472 2019-03-01 00:01:37.024 2019-03-01 00:09:29.448
# 9              3198 2019-03-01 00:02:01.694 2019-03-01 00:55:20.636
# 10              909 2019-03-01 00:02:10.900 2019-03-01 00:17:20.181
# 11              175 2019-03-01 00:02:09.528 2019-03-01 00:05:05.523
# 12              306 2019-03-01 00:02:10.900 2019-03-01 00:07:17.717
# ...

# %%
march_19_transformed_df['bikeid'] = march_19_transformed_df.index

# %%
connection_string = "postgres:12345@localhost:5432/citibike_nyc"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['march_18', 'march_19']

# %%
march_18_transformed_df.to_sql(name='march_18', con=engine, if_exists='append', index=False)

# %%
march_19_transformed_df.to_sql(name='march_19', con=engine, if_exists='append', index=False)
